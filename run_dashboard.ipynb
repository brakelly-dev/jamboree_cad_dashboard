# %%
import os

# os.chdir("jamboree_cad_dashboard")
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: c:\Users\ericb\OneDrive\Desktop\Coding_Projects\jamboree_cad_dashboard

# %%
# !python roster_preprocess.py

# %%
# !python roster_to_json.py ContingentTravelDataExport.xlsx
# Out:
# Detected column mapping:
#   unit_number     <- "Unit Number"
#   council         <- "CouncilName"
#   expected_time   <- "time"
#   transport       <- "Carrier"
#   unit_type       <- "Variant"
#   size            <- "ShuttleCount"
#   basecamp        <- "Basecamp"
#   subcamp         <- "Subcamp"
#   notes           <- "Notes"
#
# Wrote 298 units to C:\Users\ericb\OneDrive\Desktop\Coding_Projects\jamboree_cad_dashboard\jamboree_registry.json
#
# 110 warning(s):
#   - Row 11: duplicate unit name "4208A" (also row 10)
#   - Row 24 (3226): unrecognized transport "Trailer"
#   - Row 24: duplicate unit name "3226" (also row 23)
#   - Row 25: duplicate unit name "3226" (also row 24)
#   - Row 33: duplicate unit name "4402A" (also row 32)
#   - Row 34: duplicate unit name "4402A" (also row 33)
#   - Row 46 (4420): unrecognized transport "Mini-Van"
#   - Row 46: duplicate unit name "4420" (also row 45)
#   - Row 49 (3134): unrecognized transport "Mini-Van"
#   - Row 49: duplicate unit name "3134" (also row 48)
#   - Row 53 (4412A): unrecognized transport "Mini-Van"
#   - Row 53: duplicate unit name "4412A" (also row 52)
#   - Row 67: duplicate unit name "3143" (also row 66)
#   - Row 68: duplicate unit name "3143" (also row 67)
#   - Row 69 (4304B): unrecognized transport "15-Passenger Van"
#   - Row 77: duplicate unit name "4236B" (also row 76)
#   - Row 78: duplicate unit name "4236B" (also row 77)
#   - Row 81 (3228A): unrecognized transport "15-Passenger Van"
#   - Row 82 (3228B): unrecognized transport "15-Passenger Van"
#   - Row 83 (3132A): unrecognized transport "15-Passenger Van"
#   - Row 86 (4218B): unrecognized transport "15-Passenger Van"
#   - Row 87 (4218B): unrecognized transport "Trailer"
#   - Row 87: duplicate unit name "4218B" (also row 86)
#   - Row 88: duplicate unit name "4218B" (also row 87)
#   - Row 96: duplicate unit name "4340" (also row 95)
#   - Row 100 (4304A): unrecognized transport "15-Passenger Van"
#   - Row 101 (4304A): unrecognized transport "15-Passenger Van"
#   - Row 101: duplicate unit name "4304A" (also row 100)
#   - Row 102 (4424B): unrecognized transport "15-Passenger Van"
#   - Row 103: duplicate unit name "4424B" (also row 102)
#   - Row 104 (4424B): unrecognized transport "15-Passenger Van"
#   - Row 104: duplicate unit name "4424B" (also row 103)
#   - Row 109 (4417A): unrecognized transport "15-Passenger Van"
#   - Row 110 (4418): unrecognized transport "15-Passenger Van"
#   - Row 111 (4418): unrecognized transport "15-Passenger Van"
#   - Row 111: duplicate unit name "4418" (also row 110)
#   - Row 112 (4418): unrecognized transport "15-Passenger Van"
#   - Row 112: duplicate unit name "4418" (also row 111)
#   - Row 114 (3237): unrecognized transport "15-Passenger Van"
#   - Row 114: duplicate unit name "3237" (also row 113)
#   - Row 115 (3237): unrecognized transport "15-Passenger Van"
#   - Row 115: duplicate unit name "3237" (also row 114)
#   - Row 116 (3237): unrecognized transport "Trailer"
#   - Row 116: duplicate unit name "3237" (also row 115)
#   - Row 118 (4403): unrecognized transport "15-Passenger Van"
#   - Row 118: duplicate unit name "4403" (also row 117)
#   - Row 125 (3312B): unrecognized transport "15-Passenger Van"
#   - Row 125: duplicate unit name "3312B" (also row 124)
#   - Row 139 (4223A): unrecognized transport "15-Passenger Van"
#   - Row 140 (4223B): unrecognized transport "15-Passenger Van"
#   - Row 144 (4244B): unrecognized transport "Trailer"
#   - Row 144: duplicate unit name "4244B" (also row 143)
#   - Row 145: duplicate unit name "4244B" (also row 144)
#   - Row 148 (4222A): unrecognized transport "Mini-Van"
#   - Row 149: duplicate unit name "4222A" (also row 148)
#   - Row 152: duplicate unit name "3144" (also row 151)
#   - Row 153: duplicate unit name "3144" (also row 152)
#   - Row 155: duplicate unit name "3145" (also row 154)
#   - Row 157: duplicate unit name "3120A" (also row 156)
#   - Row 158: duplicate unit name "3120A" (also row 157)
#   - Row 167 (3227A): unrecognized transport "15-Passenger Van"
#   - Row 168 (3227A): unrecognized transport "15-Passenger Van"
#   - Row 168: duplicate unit name "3227A" (also row 167)
#   - Row 169: duplicate unit name "3227A" (also row 168)
#   - Row 177 (3248A): unrecognized transport "15-Passenger Van"
#   - Row 178 (3248A): unrecognized transport "15-Passenger Van"
#   - Row 178: duplicate unit name "3248A" (also row 177)
#   - Row 181: duplicate unit name "3345" (also row 180)
#   - Row 185 (3336): unrecognized transport "15-Passenger Van"
#   - Row 186 (3336): unrecognized transport "15-Passenger Van"
#   - Row 186: duplicate unit name "3336" (also row 185)
#   - Row 187: duplicate unit name "3336" (also row 186)
#   - Row 188 (3336): unrecognized transport "Trailer"
#   - Row 188: duplicate unit name "3336" (also row 187)
#   - Row 189: duplicate unit name "3336" (also row 188)
#   - Row 192: duplicate unit name "3302A" (also row 2)
#   - Row 193: duplicate unit name "3302A" (also row 192)
#   - Row 198: duplicate unit name "4316A" (also row 197)
#   - Row 204 (4316B): unrecognized transport "15-Passenger Van"
#   - Row 215: duplicate unit name "3317" (also row 214)
#   - Row 217: duplicate unit name "3332A" (also row 216)
#   - Row 218 (4242B): unrecognized transport "15-Passenger Van"
#   - Row 219: duplicate unit name "4242B" (also row 218)
#   - Row 230: duplicate unit name "3322A" (also row 229)
#   - Row 231 (4405B): unrecognized transport "15-Passenger Van"
#   - Row 238: duplicate unit name "3206" (also row 237)
#   - Row 240 (4234): unrecognized transport "15-Passenger Van"
#   - Row 257 (4345A): unrecognized transport "15-Passenger Van"
#   - Row 258 (4345A): unrecognized transport "15-Passenger Van"
#   - Row 258: duplicate unit name "4345A" (also row 257)
#   - Row 259 (4309B): unrecognized transport "15-Passenger Van"
#   - Row 260 (4309B): unrecognized transport "15-Passenger Van"
#   - Row 260: duplicate unit name "4309B" (also row 259)
#   - Row 271: duplicate unit name "4401B" (also row 270)
#   - Row 275: duplicate unit name "4211A" (also row 274)
#   - Row 277: duplicate unit name "4210B" (also row 276)
#   - Row 279: duplicate unit name "4211B" (also row 278)
#   - Row 281 (3324B): unrecognized transport "Mini-Van"
#   - Row 281: duplicate unit name "3324B" (also row 280)
#   - Row 283 (3337): unrecognized transport "Mini-Van"
#   - Row 283: duplicate unit name "3337" (also row 282)
#   - Row 284 (3205A): unrecognized transport "15-Passenger Van"
#   - Row 285 (3205A): unrecognized transport "15-Passenger Van"
#   - Row 285: duplicate unit name "3205A" (also row 284)
#   - Row 288: duplicate unit name "4305B" (also row 287)
#   - Row 291 (4310A): unrecognized transport "Mini-Van"
#   - Row 292 (4310A): unrecognized transport "Mini-Van"
#   - Row 292: duplicate unit name "4310A" (also row 291)
#   - Row 296: duplicate unit name "3325" (also row 54)
#   - Row 299: duplicate unit name "3249" (also row 298)
#
# Summary: 298 units total (222 motor coach, 76 personal vehicle)

# %%
cd cad_dashboard/
# !streamlit run app.py

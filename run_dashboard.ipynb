# %%
import os

# os.chdir("jamboree_cad_dashboard")
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: c:\Users\ericb\OneDrive\Desktop\Coding_Projects\jamboree_cad_dashboard

# %%
# !python roster_preprocess.py

# %%
# !python roster_to_json.py ContingentTravelDataExport.xlsx
# Out:
# Detected column mapping:
#   unit_number     <- "ContingentId"
#   council         <- "CouncilName"
#   expected_time   <- "time"
#   transport       <- "Carrier"
#   unit_type       <- "Variant"
#   size            <- "ShuttleCount"
#   basecamp        <- "Basecamp"
#   subcamp         <- "Subcamp"
#   notes           <- "Notes"
#
# Wrote 298 units to C:\Users\ericb\OneDrive\Desktop\Coding_Projects\jamboree_cad_dashboard\jamboree_registry.json
#
# 110 warning(s):
#   - Row 11: duplicate unit name "224" (also row 10)
#   - Row 24 (141): unrecognized transport "Trailer"
#   - Row 24: duplicate unit name "141" (also row 23)
#   - Row 25: duplicate unit name "141" (also row 24)
#   - Row 33: duplicate unit name "339" (also row 32)
#   - Row 34: duplicate unit name "339" (also row 33)
#   - Row 46 (151): unrecognized transport "Mini-Van"
#   - Row 46: duplicate unit name "151" (also row 45)
#   - Row 49 (153): unrecognized transport "Mini-Van"
# ...

# %%
cd cad_dashboard/
# !streamlit run app.py

# %%
import os

os.chdir("cad_dashboard")
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: c:\Users\ericb\OneDrive\Desktop\Coding_Projects\jamboree\cad_dashboard

# %%
# !python roster_to_json.py ContingentTravelDataExport_20260610.xlsx
# Out:
# Detected column mapping:
#   unit_number     <- "Unit name"
#   council         <- "Council"
#   expected_time   <- "Expected Arrival Time"
#   transport       <- "Transport Type"
#   unit_type       <- "Variant"
#   size            <- "Size"
#   basecamp        <- "Basecamp"
#   subcamp         <- "Subcamp"
#   notes           <- "Notes"
#
# Wrote 123 units to C:\Users\ericb\OneDrive\Desktop\Coding_Projects\jamboree\cad_dashboard\jamboree_registry.json
#
# 25 warning(s):
#   - Row 29: duplicate unit name "4211A" (also row 28)
#   - Row 31: duplicate unit name "4211B" (also row 30)
#   - Row 40: duplicate unit name "3143" (also row 39)
#   - Row 41: duplicate unit name "3143" (also row 40)
#   - Row 45: duplicate unit name "3248A" (also row 44)
#   - Row 56: duplicate unit name "4420" (also row 55)
#   - Row 58: duplicate unit name "4412A" (also row 57)
#   - Row 60: duplicate unit name "4424B" (also row 59)
#   - Row 61: duplicate unit name "4424B" (also row 60)
# ...

# %%
cd cad_dashboard/
# !streamlit run app.py
